# %%
# !ls

# %%
# %cd "drive/My Drive/for_colab/h2s/"

# %%
# !pip install --upgrade tf_slim
# !pip install scipy==1.1.0

# %%
# !ls

# %%
# !CUDA_VISIBLE_DEVICES=0 python main.py --dataset_dir=human2shark
